# %%
import sys
import PyPDF2, traceback
import docx
import pandas as pd
import glob
import cv2
import numpy as np
from PIL import Image
import pytesseract
import argparse
import os

# %%
src= glob.glob(r'C:\\Users\\Khushi.sharma\\OneDrive - Worley\\Desktop\KhushiNotebooks\\Bots_Repo\\Comments_Bot\\Data\\OneDrive_1_11-6-2020\\PDF file Having Issue\\Trial10\\*.png')
pytesseract.pytesseract.tesseract_cmd = 'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'

# %%
j = 0
for each in src:
    img = cv2.imread(each)
    h,w,channel = img.shape
    #cv2.imshow('image',img)
    for i in range(0,h):
        for j in range(0,w):
            if img[i,j][0] > 10 and img[i,j][1] > 45 and img[i,j][2] > 210:
                img[i,j][0] = 255
                img[i,j][1] = 255
                img[i,j][2] = 255
            if img[i,j][0] < 200 and img[i,j][1] < 200 and img[i,j][2] < 200:
                img[i,j][0] = 255
                img[i,j][1] = 255
                img[i,j][2] = 255
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    #dst = cv2.fastNlMeansDenoisingColored(gray,None,10,10,7,21)
    kernel2 = np.ones((2,2),np.float32)/25
    dst = cv2.filter2D(gray,-1,kernel2)
    kernel1 = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
    im = cv2.filter2D(dst, -1, kernel1)
    kernel = np.ones((2,2),np.uint8)
    #dilation = cv2.dilate(img,kernel,iterations = 1)
    erosion= cv2.erode(im,kernel,iterations = 1)
    #edges = cv2.Canny(im,100,200)
    #opening = cv2.morphologyEx(erosion, cv2.MORPH_OPEN, kernel)
    #adaptive_threshold = cv2.adaptiveThreshold(erosion, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 85, 11)
    #dilation = cv2.dilate(img,kernel,iterations = 1)
    m = 'temp'+str(j+1)+'.png'
    j = j+1
    cv2.imwrite(m,erosion)
    #config = "--psm 3"
    text = pytesseract.image_to_string(m) #config = config)
    print(text)
# Out:
# Ed
#
# Please check the drain Pit height. In another project it is provided as 1.8m. Consultant confirmed the
# height based on PDO Standard drawings ( HC Disposal Pit Details STD-2-4025-002). Please refer to this
# drawing to reverify the height. Too much height is not preferable if not necessary. This is a typical
# comment and is applicable for all the relevant drawings and Pits.
#
# .
# Design pressure will be different. Please check.
#
# \
# V4
#
#
#
# Please verify the MOC of the MSV based on latest MSR for MSV for entire Nimr Cluster. Please contact Sabri for latest MSR.
#
#
#
#
#
#
#
# instrument simples shall be as per PDO standards
# \ An J J x x .
# /
# /
# @ oN 7 Jo NN
# . Is } 2 iy ! Sse) !
# J 31 AA SSUL9 VOR RV
# CLS
# BONMGGATSOSGBAA
# A I J » BLISS
# AL lyk.
# PART Ce CN SATAP ANCE COW EE TR MI: V 34] * >t | | 1 Al l | %
# PoRENGE DRAWINGS MASI. 2 AW NO RLY SIGIN \ BY ? | oe 38
#
# ...
